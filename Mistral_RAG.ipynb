# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan99-hub/Mistral7B_Gene-Disease_RAG/blob/main/Mistral_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers einops accelerate bitsandbytes langchain

# %%
# !pip install -U langchain-community

# %%
# !pip install langchain-huggingface

# %%
# !pip install faiss-cpu

# %%
# !huggingface-cli login

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
import pandas as pd
from langchain.schema import Document

# %%
clinvar = pd.read_excel("/content/clinvar_drop.xlsx")
curated = pd.read_excel("/content/curated_grouped.xlsx")
gad = pd.read_excel("/content/gad_disease_desc.xlsx")
hpo = pd.read_excel("/content/hpo_disease_sort_desc.xlsx")
omim = pd.read_excel("/content/omim_disease_desc.xlsx")

# %%
clinvar.head()

# %%
# Create a list to hold all documents
all_documents = []

# Function to process a dataframe and add its contents to all_documents
def process_dataframe(df, source_name):
    for _, row in df.iterrows():
        try:
            text = f"Disease: {row['Genes']} | Gene: {row['Gene_IDs']} | Disease_IDs: {row['Disease_IDs']} | Description: {row['Disease_desc']}"
            all_documents.append(Document(page_content=text, metadata={"source": source_name}))
        except KeyError:
            print(f"Warning: Skipping row due to missing keys in {source_name} dataframe.")
            print(row)


# Process each dataframe
process_dataframe(clinvar, "clinvar")
process_dataframe(curated, "curated")
process_dataframe(gad, "gad")
process_dataframe(hpo, "hpo")
process_dataframe(omim, "omim")

all_documents
# Out:
# [Document(metadata={'source': 'clinvar'}, page_content='Disease: COL11A1 | Gene: 1301 | Disease_IDs: MedGen_CN071412 | Description: A disease characterized by a group of signs and symptoms that occur together and characterize a particular abnormality.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: COL11A1 | Gene: 1301 | Disease_IDs: OMIM_604841 | Description: A Stickler syndrome that has_material_basis_in heterozygous mutation in the COL11A1 gene on chromosome 1p21.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: COL11A1 | Gene: 1301 | Disease_IDs: OMIM_154780 | Description: An ectodermal dysplasia characterized by hypoplasia of the maxilla, nasal bones, and frontal sinuses, as well as calvarial thickening, myopia, early-onset cataracts, and sensorineural hearing loss that has_material_basis_in heterozygous or homozygous mutation (most frequently affecting splice sites) in the COL11A1 gene on chromosome 1p21.1. Mutations, typically null, in the COL11A1 gene may also cause Stickler syndrome.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: COL11A1 | Gene: 1301 | Disease_IDs: OMIM_228520 | Description: An osteochondrodysplasia that is characterized by shortened long bones in the arms and legs that are unusually wide at the ends, flattened vertebrae with a characteristic pinched or pear shape, and a very narrow chest in infants with short, wide ribs and a round and prominent abdomen.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: COL11A1, FTL | Gene: 2512, 1301 | Disease_IDs: MedGen_CN220053 | Description: An aortic aneurysm that is located_in the abdominal aorta.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: FTL | Gene: 2512 | Disease_IDs: OMIM_600886 | Description: A syndrome characterized by elevated circulating levels of ferritin without iron overload and early onset cataracts that has_material_basis_in heterozygous mutation in the iron responsive element in the 5-prime noncoding region of FTL on 19q13.33.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: FTL | Gene: 2512 | Disease_IDs: OMIM_615604 | Description: An amino acid metabolic disorder characterized by metabolic acidosis, elevated levels of fumaric acid in the urine, early-onset hypotonia, profound psychomotor retardation, and brain abnormalities that has_material_basis_in homozygous or compound heterozygous mutation in FH on 1q43.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: FTL | Gene: 2512 | Disease_IDs: OMIM_606159 | Description: A neurodegeneration with brain iron accumulation that has_material_basis_in autosomal dominant inheritance of mutation in the FTL gene on chromosome 19q13.33.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TTR | Gene: 7276 | Disease_IDs: MedGen_C3151470 | Description: A disease of metabolism that is characterized by extracellular tissue deposition of mis-folded amyloid fibrils built up by twisted protofilaments, deposited in the spaces between the cells of vital organs, causing disruption of organ tissue structure and function. These deposits may result in a wide range of clinical manifestations depending upon their type, location, and the amount of deposition.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TTR | Gene: 7276 | Disease_IDs: OMIM_145680 | Description: A hyperthyroxinemia that is characterized by an increased affinity for thyroxine (T4) by transthyretin in clinically euthyroid individuals and that has_material_basis_in heterozygous mutation in the TTR gene on chromosome 18q12.'),
#  Document(metadata={'source': 'clinvar'}, page_content="Disease: TTR | Gene: 7276 | Disease_IDs: OMIM_105210 | Description: An amyloidosis that is characterized by a loss of sensation in the extremities, cardiomyopathy, nephropathy, vitreous opacities, and CNS amyloidosis resulting from abnormal deposits of amyloid protein in the body's organs and tissues and has_material_basis_in autosomal dominant inheritance of mutations in the TTR gene."),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TTN, BIN1 | Gene: 7273, 274 | Disease_IDs: OMIM_255200 | Description: A centronuclear myopathy that has_material_basis_in autosomal recessive inheritance.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TTN | Gene: 7273 | Disease_IDs: OMIM_604145 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the TTN gene on chromosome 2q31.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TTN | Gene: 7273 | Disease_IDs: OMIM_600334 | Description: A distal myopathy that has_material_basis_in heterozygous mutation in the caveolin-3 gene (CAV3) on chromosome 3p25.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TTN | Gene: 7273 | Disease_IDs: OMIM_613765 | Description: A familial hypertrophic cardiomyopathy that has_material_basis_in heterozygous mutation in the TTN gene on chromosome 2q31.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TTN | Gene: 7273 | Disease_IDs: OMIM_603689 | Description: A myofibrillar myopathy characterized by adult onset of slowly progressive muscle weakness involving the diaphragm and resulting in respiratory insufficiency that has_material_basis_in heterozygous mutation in the TTN gene on chromosome 2q31.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: LMNA | Gene: 4000 | Disease_IDs: OMIM_181350 | Description: A muscular dystrophy that involves slowly worsening muscle weakness of the legs and pelvis, and has_material_basis_in X-linked recessive inheritance of mutation in the dystrophin gene on chromosome Xp21.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: LMNA | Gene: 4000 | Disease_IDs: OMIM_115200 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the LMNA gene on chromosome 1q21.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: LMNA | Gene: 4000 | Disease_IDs: OMIM_248370 | Description: A bone development disease that is characterized by underdevelopment of the lower jaw and the collarbone, bone loss at the ends of the fingers and toes, skin degeneration, and partial lipodystrophy, a condition marked by selective loss of body fat from various areas of the body.'),
#  Document(metadata={'source': 'clinvar'}, page_content="Disease: LMNA | Gene: 4000 | Disease_IDs: MedGen_CN004206 | Description: A heart conduction disease that is characterized by uncoordinated electrical activity in the heart's upper chambers (the atria), which causes the heartbeat to become fast and irregular and has symptoms palpitations, weakness, fatigue, lightheadedness, dizziness, confusion, shortness of breath and chest pain."),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: BAG3, DSP, MYH7, LMNA, RBM20, TTN | Gene: 4000, 1832, 7273, 4625, 282996, 9531 | Disease_IDs: OMIM_212110 | Description: An intrinsic cardiomyopathy that is characterized by an an enlarged heart and damage to the myocardium causing the heart to pump blood inefficiently.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: BAG3 | Gene: 9531 | Disease_IDs: OMIM_613881 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the BAG3 gene on chromosome 10q26.11.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: RBM20 | Gene: 282996 | Disease_IDs: OMIM_613172 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the RBM20 gene on chromosome 10q25.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ALMS1, TNNC1, EMD, ABCC9, TTR, MYBPC3, MYH7, PRKAG2, MYLK2, DSC2, DSP, TNNI3, MYL3, CSRP3, TPM1, MYL2, TNNT2 | Gene: 7840, 7168, 7137, 7139, 1824, 1832, 10060, 7276, 8048, 4625, 4634, 7134, 85366, 4633, 2010, 51422, 4607 | Disease_IDs: MedGen_CN001491 | Description: A heart disease and a myopathy that is characterized by deterioration of the function of the heart muscle.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYBPC3 | Gene: 4607 | Disease_IDs: OMIM_115197 | Description: A familial hypertrophic cardiomyopathy that has_material_basis_in heterozygous, homozygous, or compound heterozygous mutation in the gene encoding cardiac myosin-binding protein C (MYBPC3) on chromosome 11p11.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYBPC3 | Gene: 4607 | Disease_IDs: OMIM_115197 | Description: A hypertrophic cardiomyopathy that is characterized by thickening of the heart muscle and has_material_basis_in autosomal dominant inheritance of one or more gene mutations.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYBPC3 | Gene: 4607 | Disease_IDs: OMIM_615396 | Description: An intrinsic cardiomyopathy characterized by distinctive (spongy) morphological appearance of the LV myocardium.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ACTN2, MYBPC3, MYH7, MYL3, JPH2 | Gene: 57158, 4625, 88, 4634, 4607 | Disease_IDs: OMIM_192600 | Description: A hypertrophic cardiomyopathy that is characterized by thickening of the heart muscle and has_material_basis_in autosomal dominant inheritance of one or more gene mutations.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TNNI3, MYH7 | Gene: 7137, 4625 | Disease_IDs: MedGen_C0007196 | Description: An intrinsic cardiomyopathy characterized by impaired ventricular filling, with normal or decreased diastolic volume of either or both ventricles typically resulting from increased stiffness of the myocardium.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYH7 | Gene: 4625 | Disease_IDs: OMIM_613426 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the MYH7 gene on chromosome 14q12.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYH7 | Gene: 4625 | Disease_IDs: SNOMED CT_35728003 | Description: A hypertrophic cardiomyopathy that is characterized by thickening of the heart muscle and has_material_basis_in autosomal dominant inheritance of one or more gene mutations.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYH7 | Gene: 4625 | Disease_IDs: OMIM_192600 | Description: A hypertrophic cardiomyopathy that is characterized by thickening of the heart muscle and has_material_basis_in autosomal dominant inheritance of one or more gene mutations.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYH7 | Gene: 4625 | Disease_IDs: MedGen_C3150690 | Description: An intrinsic cardiomyopathy characterized by distinctive (spongy) morphological appearance of the LV myocardium.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYH7 | Gene: 4625 | Disease_IDs: MedGen_CN167392 | Description: An intrinsic cardiomyopathy characterized by distinctive (spongy) morphological appearance of the LV myocardium.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYH7 | Gene: 4625 | Disease_IDs: OMIM_160500 | Description: A distal myopathy that is characterized by autosomal dominant inheritance that has_material_basis_in mutation in the MYH7 gene on chromosome 14q11.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYH7 | Gene: 4625 | Disease_IDs: OMIM_608358 | Description: A congenital myopathy characterized by accumulation of ATPase and antibody positive myosin in hyaline subsarcolemmal bodies in type I muscle fibers and a variable development of muscle weakness that has_material_basis_in mutation in MYH7 on 14q11.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TNNI3 | Gene: 7137 | Disease_IDs: OMIM_613286 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the TNNI3 gene on chromosome 19q13.42.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TNNI3 | Gene: 7137 | Disease_IDs: OMIM_613690 | Description: A familial hypertrophic cardiomyopathy that has_material_basis_in heterozygous mutation in the TNNI3 gene on chromosome 19q13.4.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TNNI3 | Gene: 7137 | Disease_IDs: OMIM_115210 | Description: A restrictive cardiomyopathy that has_material_basis_in heterozygous mutation in the TNNI3 gene on chromosome 19q13.42.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: RYR1 | Gene: 6261 | Disease_IDs: OMIM_117000 | Description: A congenital myopathy that is characterized by muscle weakness primarily affecting the proximal muscles of the lower limbs beginning in infancy or early childhood, although later onset of symptoms has been reported and that has_material_basis_in heterozygous mutation in the ryanodine receptor-1 gene (RYR1) on chromosome 19q13. Heterozygous mutation in the RYR1 gene also causes susceptibility to malignant hyperthermia-1 (MHS1), patients with CMYP1A are at risk for MHS. Biallelic mutations in the RYR1 gene cause autosomal recessive CMYP1B, which shows overlapping features, but is typically more severe.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: RYR1 | Gene: 6261 | Disease_IDs: OMIM_255320 | Description: A chronic progressive external ophthalmoplegia characterized by adult onset of progressive external ophthalmoplegia, exercise intolerance, muscle weakness, and signs and symptoms of spinocerebellar ataxia that has_material_basis_in homozygous or compound heterozygous mutation in the RNASEH1 gene on chromosome 2p25.3.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: RYR1, ACTA1, MYH7 | Gene: 4625, 58, 6261 | Disease_IDs: OMIM_255310 | Description: A congenital fiber-type disproportion characterized by bilateral ptosis, facial weakness, impaired suckling, generalized hypotonia, and respiratory insufficiency that has_material_basis_in mutation in the chromosome region Xq13.1-q22.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ACTA1 | Gene: 58 | Disease_IDs: MedGen_C2750537 | Description: A congenital myopathy that is characterized by the onset of muscle weakness in infancy manifest as neonatal hypotonia, delayed motor development, and often distal contractures and that has_material_basis_in homozygous or compound heterozygous mutation in the gene encoding titin (TTN) on chromosome 2q31.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ACTA1 | Gene: 58 | Disease_IDs: MedGen_C1834339 | Description: A congenital myopathy that is characterized by the onset of muscle weakness in infancy manifest as neonatal hypotonia, delayed motor development, and often distal contractures and that has_material_basis_in homozygous or compound heterozygous mutation in the gene encoding titin (TTN) on chromosome 2q31.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ACTA1 | Gene: 58 | Disease_IDs: OMIM_161800 | Description: A nemaline myopathy that has_material_basis_in homozygous, compound heterozygous, or heterozygous mutation in the ACTA1 gene on chromosome 1q42.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ACTA1 | Gene: 58 | Disease_IDs: MedGen_CN187050 | Description: A nemaline myopathy that has_material_basis_in homozygous, compound heterozygous, or heterozygous mutation in the ACTA1 gene on chromosome 1q42.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: JPH2 | Gene: 57158 | Disease_IDs: OMIM_613873 | Description: A familial hypertrophic cardiomyopathy that has_material_basis_in heterozygous mutation in the junctophilin gene (JPH2) on chromosome 20q12.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TNNT2 | Gene: 7139 | Disease_IDs: MedGen_CN001491 | Description: No description found.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TNNT2 | Gene: 7139 | Disease_IDs: OMIM_115195 | Description: A hypertrophic cardiomyopathy that is characterized by thickening of the heart muscle and has_material_basis_in autosomal dominant inheritance of one or more gene mutations.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TNNT2 | Gene: 7139 | Disease_IDs: OMIM_601494 | Description: An intrinsic cardiomyopathy characterized by distinctive (spongy) morphological appearance of the LV myocardium.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ABCC9 | Gene: 10060 | Disease_IDs: OMIM_614050 | Description: An atrial fibrillation that has_material_basis_in autosomal dominant inheritance of the familial atrial fibrillation (ATFB) genes.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ABCC9 | Gene: 10060 | Disease_IDs: OMIM_608569 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the ABCC9 gene on chromosome 12p12.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ABCC9 | Gene: 10060 | Disease_IDs: OMIM_239850 | Description: An osteochondrodysplasia that is characterized by congenital hypertrichosis, neonatal macrosomia, and cardiomegaly.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PRKAG2 | Gene: 51422 | Disease_IDs: OMIM_600858 | Description: A familial hypertrophic cardiomyopathy that has_material_basis_in heterozygous mutation in the gene encoding the gamma-2 regulatory subunit of AMP-activated protein kinase (PRKAG2).'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TPM1 | Gene: 7168 | Disease_IDs: OMIM_611878 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the TPM1 gene on chromosome 15q22.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TPM1 | Gene: 7168 | Disease_IDs: OMIM_115196 | Description: A hypertrophic cardiomyopathy that is characterized by thickening of the heart muscle and has_material_basis_in autosomal dominant inheritance of one or more gene mutations.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TNNC1 | Gene: 7134 | Disease_IDs: OMIM_611879 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the TNNC1 gene on chromosome 3p.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TNNC1 | Gene: 7134 | Disease_IDs: OMIM_613243 | Description: A familial hypertrophic cardiomyopathy that has_material_basis_in heterozygous mutation in the TNNC1 gene on chromosome 3p21.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: CSRP3 | Gene: 8048 | Disease_IDs: OMIM_607482 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the CSRP3 gene on chromosome 11p15.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: CSRP3 | Gene: 8048 | Disease_IDs: OMIM_612124 | Description: A familial hypertrophic cardiomyopathy that has_material_basis_in heterozygous mutation in the CSRP3 gene on chromosome 11p15.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYL2 | Gene: 4633 | Disease_IDs: OMIM_608758 | Description: A familial hypertrophic cardiomyopathy that has_material_basis_in mutation in the MYL2 gene.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: EMD | Gene: 2010 | Disease_IDs: OMIM_310300 | Description: A myopathy is characterized by progressive skeletal muscle weakness degeneration.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: EMD | Gene: 2010 | Disease_IDs: MedGen_CN069573 | Description: A myopathy is characterized by progressive skeletal muscle weakness degeneration.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYLK2 | Gene: 85366 | Disease_IDs: MedGen_CN068809 | Description: An intrinsic cardiomyopathy that is characterized by abnormal thickening (hypertrophy) of the heart without any obvious cause.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ALMS1 | Gene: 7840 | Disease_IDs: OMIM_203800 | Description: A syndrome that is characterized by multiorgan dysfunction. The key features are childhood obesity, blindness due to congenital retinal dystrophy, and sensorineural hearing loss with autosomal recessive inheritance and has_material_basis_in mutations in the ALMS1 gene.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNH2, SCN5A, KCNE2 | Gene: 9992, 6331, 3757 | Disease_IDs: SNOMED CT_442946007 | Description: An autosomal genetic disease that is characterized by delayed repolarization of the heart following a heartbeat increases the risk of episodes of torsade de pointes (TDP, a form of irregular heartbeat that originates from the ventricles).'),
#  Document(metadata={'source': 'clinvar'}, page_content="Disease: KCNQ1, SCN5A, KCNE2 | Gene: 9992, 6331, 3784 | Disease_IDs: MedGen_C1963067 | Description: A heart conduction disease that is characterized by uncoordinated electrical activity in the heart's upper chambers (the atria), which causes the heartbeat to become fast and irregular and has symptoms palpitations, weakness, fatigue, lightheadedness, dizziness, confusion, shortness of breath and chest pain."),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNH2, KCNJ2, KCNE2, ANK2, SCN5A, KCNQ1 | Gene: 9992, 3784, 3757, 3759, 6331, 287 | Disease_IDs: SNOMED CT_442917000 | Description: An autosomal genetic disease that is characterized by delayed repolarization of the heart following a heartbeat increases the risk of episodes of torsade de pointes (TDP, a form of irregular heartbeat that originates from the ventricles).'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNQ1, ANK2, SCN5A | Gene: 3784, 6331, 287 | Disease_IDs: SNOMED CT_31722008 | Description: A palmoplantar keratosis characterized by autosomal recessive inheritance of symmetric palmoplantar hyperkeratosis that progressively extends to the dorsal surfaces of hands and feet and ichthyotic changes elsewhere that has_material_basis_in homozygous mutation in the SLURP1 gene on chromosome 8q24.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNQ1, KCNH2, SCN5A | Gene: 3784, 6331, 3757 | Disease_IDs: OMIM_272120 | Description: A syndrome that is characterized by the sudden death of an infant that is not predicted by medical history and remains unexplained after a thorough forensic autopsy and detailed death scene investigation.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: CACNA1C, SCN5A | Gene: 6331, 775 | Disease_IDs: SNOMED CT_418818005 | Description: A heart conduction disease that is characterized by abnormal electrocardiogram (ECG) findings and an increased risk of sudden cardiac death.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN5A | Gene: 6331 | Disease_IDs: OMIM_601144 | Description: A Brugada syndrome that has_material_basis_in heterozygous mutation in the SCN5A gene on chromosome 3p22.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN5A | Gene: 6331 | Disease_IDs: MedGen_CN001497 | Description: An intrinsic cardiomyopathy that is characterized by an an enlarged heart and damage to the myocardium causing the heart to pump blood inefficiently.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN5A | Gene: 6331 | Disease_IDs: OMIM_601154 | Description: A dilated cardiomyopathy that has_material_basis_in mutation in the SCN5A gene on chromosome 3p22.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN5A | Gene: 6331 | Disease_IDs: MedGen_C1861983 | Description: An atrioventricular block characterized by the presence of conduction system disease of any form, which is diagnosed on or before 28 days of life.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN5A | Gene: 6331 | Disease_IDs: OMIM_603830 | Description: A long QT syndrome that has_material_basis_in dominant inheritance of mutation in the SCN5A gene on chromosome 3p22.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN5A | Gene: 6331 | Disease_IDs: OMIM_113900 | Description: A heart conduction disease characterized by autosomal dominant inheritance of a cardiac conduction defect that may progress to complete atrioventricular (AV) block and maybe asymptomatic of manifest as shortness of breath, dizziness, syncope, abdominal pain, heart failure or sudden death.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN5A | Gene: 6331 | Disease_IDs: OMIM_608567 | Description: Xref MGI.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNJ2, SCN5A | Gene: 6331, 3759 | Disease_IDs: SNOMED CT_25569003 | Description: A tachycardia that is associated with the generation of improper electrical impulses within the ventricles, characterized by an electrocardiogram showing a rate of greater than 120 BPM and three or more wide QRS complexes in a row.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNQ1 | Gene: 3784 | Disease_IDs: OMIM_220400 | Description: OMIM mapping confirmed by DO. [SN].'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNQ1 | Gene: 3784 | Disease_IDs: OMIM_192500 | Description: A long QT syndrome that has_material_basis_in dominant inheritance of mutation in the KCNQ1 gene on chromosome 11p15.5-p15.4.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ANK2 | Gene: 287 | Disease_IDs: SNOMED CT_248650006 | Description: Arrhythmia is a cardiovascular system symptom consisting of an alteration in rhythm of the heartbeat either in time or force.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN1B, RYR2, ANK2 | Gene: 6324, 6262, 287 | Disease_IDs: OMIM_115000 | Description: A heart disease characterized by a broad spectrum of cardiac arrhythmias including; bradycardia, sinus arrhythmia, delayed conduction/conduction block, idiopathic ventricular fibrillation, and catecholaminergic polymorphic ventricular tachycardia that has_material_basis_in heterozygous mutation in the ANK2 gene on chromosome 4q25-q26.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN1B | Gene: 6324 | Disease_IDs: OMIM_615377 | Description: An atrial fibrillation that has_material_basis_in autosomal dominant inheritance of the familial atrial fibrillation (ATFB) genes.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN1B | Gene: 6324 | Disease_IDs: OMIM_612838 | Description: A Brugada syndrome that has_material_basis_in heterozygous mutation in the SCN1B gene on chromosome 19q13.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN1B | Gene: 6324 | Disease_IDs: OMIM_604233 | Description: A generalized epilepsy with febrile seizures plus that has_material_basis_in heterozygous mutation in SCN1B on chromosome 19q13.11.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SCN1B, SCN5A | Gene: 6331, 6324 | Disease_IDs: MedGen_C2748542 | Description: A physical disorder that has_material_basis_in homozygous or compound heterozygous mutation in the PLD1 gene on chromosome 3q26.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNH2 | Gene: 3757 | Disease_IDs: OMIM_613688 | Description: A long QT syndrome that has_material_basis_in dominant inheritance of mutation in the KCNH2 gene on chromosome 7q36.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNH2 | Gene: 3757 | Disease_IDs: SNOMED CT_95281009 | Description: A syndrome that is characterized by the sudden death of an infant that is not predicted by medical history and remains unexplained after a thorough forensic autopsy and detailed death scene investigation.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KCNH2 | Gene: 3757 | Disease_IDs: Orphanet_ORPHA51083 | Description: A heart conduction disease that is characterized by heart arrhythmia defined as a short QT interval on an EKG (less than 300 ms) that does not significantly change with heart rate, tall and peaked T waves, and a structurally normal heart.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: RYR2 | Gene: 6262 | Disease_IDs: OMIM_600996 | Description: An intrinsic cardiomyopathy that is characterized by hypokinetic areas involving the free wall of the right ventricle, with fibrofatty replacement of the right ventricular myocardium, with associated arrhythmias originating in the right ventricle and limited or no involvement of the left ventricle.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: RYR2 | Gene: 6262 | Disease_IDs: OMIM_604772 | Description: A heart conduction disease characterized by adrenergically induced ventricular tachycardia manifesting as syncope and sudden death during exercise, stress or catecholamine infusion without the presence of structural cardiac abnormalities.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: CACNA1C, RYR2 | Gene: 6262, 775 | Disease_IDs: OMIM_603829 | Description: An atrial fibrillation that has_material_basis_in autosomal dominant inheritance of the familial atrial fibrillation (ATFB) genes.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSP, PKP2, TMEM43, DSC2 | Gene: 1824, 1832, 79188, 5318 | Disease_IDs: SNOMED CT_253528005 | Description: An intrinsic cardiomyopathy that is characterized by hypokinetic areas involving the free wall of the right ventricle, with fibrofatty replacement of the right ventricular myocardium, with associated arrhythmias originating in the right ventricle and limited or no involvement of the left ventricle.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TMEM43 | Gene: 79188 | Disease_IDs: OMIM_604400 | Description: An intrinsic cardiomyopathy that is characterized by hypokinetic areas involving the free wall of the right ventricle, with fibrofatty replacement of the right ventricular myocardium, with associated arrhythmias originating in the right ventricle and limited or no involvement of the left ventricle.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TMEM43 | Gene: 79188 | Disease_IDs: OMIM_614302 | Description: An Emery-Dreifuss muscular dystrophy that has_material_basis_in an autosomal dominant mutation of the TMEM43 gene on chromosome 3p25.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSC2 | Gene: 1824 | Disease_IDs: OMIM_610476 | Description: An intrinsic cardiomyopathy that is characterized by hypokinetic areas involving the free wall of the right ventricle, with fibrofatty replacement of the right ventricular myocardium, with associated arrhythmias originating in the right ventricle and limited or no involvement of the left ventricle.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSC2 | Gene: 1824 | Disease_IDs: MedGen_CN128708 | Description: A nonepidermolytic palmoplantar keratoderma characterized by striate palmoplantar keratoderma, sparse and woolly hair, leukonychia, and the absence of cardiomyopathy symptoms or findings on echocardiography and electrocardiogram that has_material_basis_in homozygous mutation in the KANK2 gene on chromosome 19p13.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PKP2 | Gene: 5318 | Disease_IDs: OMIM_609040 | Description: An intrinsic cardiomyopathy that is characterized by hypokinetic areas involving the free wall of the right ventricle, with fibrofatty replacement of the right ventricular myocardium, with associated arrhythmias originating in the right ventricle and limited or no involvement of the left ventricle.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSP | Gene: 1832 | Disease_IDs: OMIM_607450 | Description: An intrinsic cardiomyopathy that is characterized by hypokinetic areas involving the free wall of the right ventricle, with fibrofatty replacement of the right ventricular myocardium, with associated arrhythmias originating in the right ventricle and limited or no involvement of the left ventricle.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSP | Gene: 1832 | Disease_IDs: MedGen_CN001541 | Description: A congestive heart failure characterized by a sudden stop in effective blood circulation due to the failure of the heart to contract effectively or at all.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSP | Gene: 1832 | Disease_IDs: OMIM_605676 | Description: A nonepidermolytic palmoplantar keratoderma characterized by striate palmoplantar keratoderma, sparse and woolly hair, leukonychia, and the absence of cardiomyopathy symptoms or findings on echocardiography and electrocardiogram that has_material_basis_in homozygous mutation in the KANK2 gene on chromosome 19p13.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSP | Gene: 1832 | Disease_IDs: OMIM_615821 | Description: A nonepidermolytic palmoplantar keratoderma characterized by striate palmoplantar keratoderma, sparse and woolly hair, leukonychia, and the absence of cardiomyopathy symptoms or findings on echocardiography and electrocardiogram that has_material_basis_in homozygous mutation in the KANK2 gene on chromosome 19p13.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSP | Gene: 1832 | Disease_IDs: OMIM_609638 | Description: A vesiculobullous skin disease that is characterized by formation of blisters with only minor skin trauma, which can cause widespread wounds, dehydration, electrolyte abnormalities, and severe infection, frequently develops_from mutations in connective tissue elements, including genes encoding keratin, collagen, and laminin.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSP | Gene: 1832 | Disease_IDs: OMIM_612908 | Description: A palmoplantar keratosis that is characterized by hyperkeratotic lesions that are restricted to the pressure regions extending longitudinally in the length of each finger to the palm.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSP | Gene: 1832 | Disease_IDs: OMIM_607655 | Description: A hair disease characterized by fine and tightly curled hair that grows slowly and stops growing after a few inches with hair shafts that display trichorrhexis nodosa and tapered ends.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DSP, SCN5A | Gene: 1832, 6331 | Disease_IDs: SNOMED CT_71908006 | Description: A cardiac fibrillation associated with quivering of the lower chambers of the heart, preventing blood from being pumped and causing cardiac arrest.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ZFPM2 | Gene: 23414 | Disease_IDs: OMIM_616067 | Description: A 46 XY sex reversal characterized by an XY karyotype, phenotypically female genitalia and failure to develop secondary sexual characteristics at puberty including menstruation that has_material_basis_in hemizygous duplication of the NR0B1 gene on chromosome Xp21.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ZFPM2 | Gene: 23414 | Disease_IDs: OMIM_610187 | Description: A diaphragm disease characterized by the lack of development of all or part of the diaphragm, which results in an abnormal opening that allows the stomach and intestines to move into the chest cavity and crowd the heart and lungs.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ZFPM2 | Gene: 23414 | Disease_IDs: SNOMED CT_7484005 | Description: OMIM mapping confirmed by DO. [SN].'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: JAG1 | Gene: 182 | Disease_IDs: OMIM_118450 | Description: A liver disease that is characterized by an accumulation of bile in the liver resulting from a reducted number of liver small bile ducts.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: JAG1 | Gene: 182 | Disease_IDs: MedGen_C1866053 | Description: A syndrome characterized by congenital heart defects, hamartomas of tongue, and polysyndactyly that has_material_basis_in homozygous or compound heterozygous mutation in the WDPCP gene on chromosome 2p15.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: NKX2-5, ZFPM2, GATA6, JAG1 | Gene: 1482, 23414, 2627, 182 | Disease_IDs: OMIM_187500 | Description: OMIM mapping confirmed by DO. [LS].'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: NKX2-5 | Gene: 1482 | Disease_IDs: OMIM_108900 | Description: An atrial heart septal defect that has_material_basis_in heterozygous mutation in the NKX2-5 gene on chromosome 5q35.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: NKX2-5 | Gene: 1482 | Disease_IDs: OMIM_225250 | Description: A congenital hypothyroidism that has_material_basis_in heterozygous mutation in the NKX2-5 gene on chromosome 5q35.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: NKX2-5 | Gene: 1482 | Disease_IDs: OMIM_614432 | Description: A heart septal defect characterized by an opening in the interventricular septum, causing a shunt between ventricles.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: GATA6 | Gene: 2627 | Disease_IDs: OMIM_614474 | Description: A congenital heart septal defect characterized by an abnormal or inadequate fusion of the superior and inferior endocardial cushions with the mid portion of the atrial septum and the muscular portion of the ventricular septum, thus allowing extra blood to circulate the lungs.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: GATA6 | Gene: 2627 | Disease_IDs: OMIM_600001 | Description: A syndrome characterized by partial pancreatic agenesis, diabetes mellitus, and heart anomalies that has_material_basis_in heterozygous mutation in GATA6 on chromosome 18q11.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: COL4A5 | Gene: 1287 | Disease_IDs: OMIM_301050 | Description: An Alport syndrome that has_material_basis_in homozygous or compound heterozygous mutation in the COL4A3 or the COL4A4 gene, both of which map to chromosome 2q.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: IFIH1 | Gene: 64135 | Disease_IDs: OMIM_615846 | Description: A Perrault syndrome that is characterized by sensorineural hearing loss and ovarian insufficiency in females and that has_material_basis_in compound heterozygous or homozygous mutation in the DAP3 gene on chromosome 1q22.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: APP | Gene: 351 | Disease_IDs: OMIM_104300 | Description: A tauopathy that is characterized by memory lapses, confusion, emotional instability and progressive loss of mental ability and results in progressive memory loss, impaired thinking, disorientation, and changes in personality and mood starting and leads in advanced cases to a profound decline in cognitive and physical functioning and is marked histologically by the degeneration of brain neurons especially in the cerebral cortex and by the presence of neurofibrillary tangles and plaques containing beta-amyloid.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ENAM | Gene: 10117 | Disease_IDs: OMIM_104500 | Description: An amelogenesis imperfecta that has_material_basis_in heterozygous mutation in the enamelin gene (ENAM) on chromosome 4q13.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: KLK4 | Gene: 9622 | Disease_IDs: MedGen_C1290537 | Description: An amelogenesis imperfecta that has_material_basis_in homozygous mutation in the matrix metalloproteinase-20 gene (MMP20).'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: FAM83H | Gene: 286077 | Disease_IDs: OMIM_130900 | Description: An amelogenesis imperfecta type 3 that is characterized by hypocalcified enamel in both the primary and secondary dentition and that has_material_basis_in homozygous mutation in the RELT gene on chromosome 11q13.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ST3GAL5 | Gene: 8869 | Disease_IDs: OMIM_609056 | Description: An infancy electroclinical syndrome that is characterized by afebrile partial complex or generalized tonic-clonic seizures occurring between 3 and 12 months of age with a good response to medication and no neurologic sequelae.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: UBQLN2 | Gene: 29978 | Disease_IDs: OMIM_300857 | Description: An amyotrophic lateral sclerosis that has_material_basis_in mutation in the UBQLN2 gene on chromosome X.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SIGMAR1 | Gene: 10280 | Disease_IDs: OMIM_614373 | Description: An amyotrophic lateral sclerosis that has_material_basis_in mutation in the SIGMAR1 gene (SETX) on chromosome 9.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PFN1 | Gene: 5216 | Disease_IDs: OMIM_614808 | Description: An amyotrophic lateral sclerosis that has_material_basis_in mutation in the PFN1 gene on chromosome 17.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SOD1 | Gene: 6647 | Disease_IDs: MedGen_C3542025 | Description: An amyotrophic lateral sclerosis that has_material_basis_in mutation in the FUS gene on chromosome 16.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SOD1 | Gene: 6647 | Disease_IDs: OMIM_105400 | Description: An amyotrophic lateral sclerosis that has_material_basis_in mutation in the SOD1 gene on chromosome 21. The most common type of familial ALS.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: CPN1 | Gene: 1369 | Disease_IDs: OMIM_212070 | Description: A plasma protein metabolism disease characterized by low levels of carboxypeptidase N in the serum that may result in episodic angioedema, chronic urticaria, asthma and/or allergic hypersensitivity that has_material_basis_in homozygous or compound heterozygous mutation in the CPN1 gene on chromosome 10q24.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SLC12A6 | Gene: 9990 | Disease_IDs: OMIM_218000 | Description: A neurodegenerative disease characterized by autosomal recessive inheritance with early onset of severe sensory-motor polyneuropathy, variable degree of agenesis of the corpus callosum, amyotrophy, hypotonia, and cognitive impairment that has_material_basis_in homozygous or compound heterozygous mutation in the SLC12A6 gene on chromosome 15q14.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ABCB7 | Gene: 22 | Disease_IDs: OMIM_301310 | Description: A sideroblastic anemia that is characterized by decreased production of hemoglobin and ataxia and has_material_basis_in the mutation in the ABCB7 gene.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SLC25A38 | Gene: 54977 | Disease_IDs: OMIM_205950 | Description: A sideroblastic anemia that is characterized by homozygous or compound heterozygous mutation in the GLRX5 gene on chromosome 14q32.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: UBE3A | Gene: 7337 | Disease_IDs: OMIM_105830 | Description: A syndrome that is characterized by delayed development, intellectual disability, severe speech impairment, and problems with movement and balance.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: RSPO4 | Gene: 343637 | Disease_IDs: OMIM_206800 | Description: A nonsyndromic congenital nail disorder that is characterized by complete absence or severe hypoplasia of all fingernails and toenails without significant bone anomalies, and that has_material_basis_in homozygous or compound heterozygous mutation in the R-spondin-4 gene on chromosome 20p13.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SMOC1 | Gene: 64093 | Disease_IDs: OMIM_206920 | Description: A syndrome that is characterized by autosomal recessive inheritance of bilateral or unilateral clinical anophthalmia or microphthalmia and synostosis, syndactyly, oligodactyly and/or polydactyly that has_material_basis_in homozygous mutation in the SMOC1 gene on chromosome 14q24.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SERPINF2 | Gene: 5345 | Disease_IDs: OMIM_262850 | Description: An amino acid metabolic disorder characterized by onset at birth of encephalopathy, lack of normal development, seizures, and hypotonia associated with variable brain abnormalities that has_material_basis_in homozygous mutation in the GLUL gene on chromosome 1q25.3.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SERPINC1 | Gene: 462 | Disease_IDs: OMIM_613118 | Description: A thrombophilia that is characterized by the tendency to form clots in the veins.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ACTA2 | Gene: 59 | Disease_IDs: OMIM_611788 | Description: An aortic aneurysm that is located_in the thoracic aorta.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MYLK | Gene: 4638 | Disease_IDs: OMIM_613780 | Description: An aortic aneurysm that is located_in the thoracic aorta.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PRKG1 | Gene: 5592 | Disease_IDs: OMIM_615436 | Description: An aortic aneurysm that is located_in the thoracic aorta.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MFAP5 | Gene: 8076 | Disease_IDs: OMIM_616166 | Description: An aortic aneurysm that is located_in the thoracic aorta.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SMAD6 | Gene: 4091 | Disease_IDs: OMIM_614823 | Description: A bicuspid aortic valve disease that has_material_basis_in heterozygous mutation in the SMAD6 gene on chromosome 15q22.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: FOXE3 | Gene: 2301 | Disease_IDs: OMIM_107250 | Description: An eye disease that is characterized by iris hypoplasia, an enlarged or reduced corneal diameter, corneal vascularization and opacity, posterior embryotoxon, corectopia, polycoria, an abnormal iridocorneal angle, ectopia lentis, and anterior synechiae between the iris and posterior corneal surface and is located_in the anterior segment of the eye.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: FOXE3 | Gene: 2301 | Disease_IDs: OMIM_610256 | Description: OMIM mapping confirmed by DO. [SN].'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: BMS1 | Gene: 9790 | Disease_IDs: OMIM_107600 | Description: A skin disease characterized by localized areas of missing skin that resemble ulcers or oopen wounds in new borns and that has_material_basis_in heterozygous mutation in the BMS1 gene on chromosome 10q11.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: COX7B | Gene: 1349 | Disease_IDs: OMIM_300887 | Description: A linear skin defects with multiple congenital anomalies characterized by linear skin defects, microcephaly, facial dysmorphism, and other congenital anomalies that has_material_basis_in heterozygous mutation in the COX7B gene on chromosome Xq21.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ABCC11 | Gene: 85320 | Disease_IDs: OMIM_117800 | Description: An apocrine sweat gland cancer that derives_from epithelial cells of glandular origin.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: HSD11B2 | Gene: 3291 | Disease_IDs: OMIM_218030 | Description: A steroid inherited metabolic disorder characterized by decreased conversion of biologically active cortisol to inactive cortisone resulting in low aldosterone levels, metabolic alkalosis, hypernatremia, hypokalemia and early-onset severe hypertension that has_material_basis_in homozygous or compound heterozygous mutation in the HSD11B2 gene on chromosome 16.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ARG1 | Gene: 383 | Disease_IDs: OMIM_207800 | Description: An urea cycle disorder that involves arginase deficiency resulting in elevated levels of plasma arginine.'),
# ...
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PHKA2 | Gene: 5256 | Disease_IDs: MedGen_C2748941 | Description: A glycogen metabolism disorder that has_material_basis_in enzymes deficiencies necessary in the processing of glycogen synthesis or breakdown within muscles, liver, and other cell types.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PHKA2 | Gene: 5256 | Disease_IDs: OMIM_306000 | Description: A glycogen storage disease IX characterized by hepatomegaly, growth retardation, elevation of glutamate-pyruvate transaminase and glutamate-oxaloacetate transaminase, hypercholesterolemia, hypertriglyceridemia, and fasting hyperketosis, but symptoms gradually disappear with age, that has_material_basis_in X-linked inheritance of mutation in the PHKA2 gene on chromosome Xp22.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PGAM2 | Gene: 5224 | Disease_IDs: OMIM_261670 | Description: A glycogen storage disease IX characterized by hepatomegaly, growth retardation, elevation of glutamate-pyruvate transaminase and glutamate-oxaloacetate transaminase, hypercholesterolemia, hypertriglyceridemia, and fasting hyperketosis, but symptoms gradually disappear with age, that has_material_basis_in X-linked inheritance of mutation in the PHKA2 gene on chromosome Xp22.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: GAA | Gene: 2548 | Disease_IDs: MedGen_CN068792 | Description: A glycogen storage disease that has_material_basis_in deficiency of the lysosomal acid alpha-glucosidase enzyme resulting in damage to muscle and nerve cells due to an accumulation of glycogen in the lysosome.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: GAA | Gene: 2548 | Disease_IDs: MedGen_C0751173 | Description: A glycogen storage disease that has_material_basis_in deficiency of the lysosomal acid alpha-glucosidase enzyme resulting in damage to muscle and nerve cells due to an accumulation of glycogen in the lysosome.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: GAA | Gene: 2548 | Disease_IDs: OMIM_232300 | Description: A glycogen storage disease that has_material_basis_in deficiency of the lysosomal acid alpha-glucosidase enzyme resulting in damage to muscle and nerve cells due to an accumulation of glycogen in the lysosome.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PYGM | Gene: 5837 | Disease_IDs: OMIM_232600 | Description: A glycogen storage disease that is characterized by onset of exercise intolerance and muscle cramps in childhood or adolescence and that has_material_basis_in homozygous or compound heterozygous mutation in the PYGM gene, which encodes muscle glycogen phosphorylase, on chromosome 11q13.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PYGL | Gene: 5836 | Disease_IDs: OMIM_232700 | Description: A glycogen storage disease characterized by enlargement of the liver, moderately low blood sugar, elevated levels of acetone and other ketone bodies in the blood and moderate growth retardation.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PFKM | Gene: 5213 | Disease_IDs: OMIM_232800 | Description: A glycogen storage disease that is characterized by exercise intolerance, muscle cramping, exertional myopathy, and compensated hemolysis and that has_material_basis_in homozygous or compound heterozygous mutation in the PFKM gene, which encodes muscle phosphofructokinase, on chromosome 12q13.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PIGM | Gene: 93183 | Disease_IDs: OMIM_610293 | Description: A familial chylomicronemia syndrome characterized by refactory fasting hyperchylomicronemia, and elevated plasma triglyceride levels that has_material_basis_in homozygous or compound heterozygous mutation in the GPIHBP1 gene on chromosome 8q24.3.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: HSD17B4 | Gene: 3295 | Disease_IDs: OMIM_261515 | Description: A peroxisomal disease characterized by, in severe cases, infantile-onset of hypotonia, seizures, and abnormal facial features with most dying before age 2 years that has_material_basis_in homozygous or compound heterozygous mutation in the HSD17B4 gene on chromosome 5q2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: HSD17B4 | Gene: 3295 | Disease_IDs: OMIM_233400 | Description: A disorder of sexual development that is characterized by a progressive loss of germ cells on the developing gonads of an embryo.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: CYBA | Gene: 1535 | Disease_IDs: OMIM_233690 | Description: A chronic granulomatous disease characterized by autosomal recessive inheritance that has_material_basis_in mutation in the CYBA gene on chromosome 16q24.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: NBEAL2 | Gene: 23218 | Disease_IDs: OMIM_139090 | Description: A blood platelet disease characterized by selective deficiency in the number and contents of platelet alpha-granules, macrothrombocytopenia, enlarged platelets, myelofibrosis, splenomegaly, and increased bleeding time that has_material_basis_in homozygous or compound heterozygous mutation in the NBEAL2 gene on chromosome 3p21.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: RAB27A | Gene: 5873 | Disease_IDs: OMIM_607624 | Description: A Griscelli syndrome characterized by silvery gray sheen of the hair, hypopigmentation of the skin and immunodeficiency with or without neurologic impairment that has_material_basis_in mutation in the RAB27A gene on chromosome 15q21.3.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: MLPH | Gene: 79083 | Disease_IDs: OMIM_609227 | Description: A Griscelli syndrome characterized by isolated silvery gray sheen of the hair and hypopigmentation of the skin that has_material_basis_in mutation in the MLPH or MYO5A genes.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: EFTUD2 | Gene: 9343 | Disease_IDs: OMIM_610536 | Description: A syndrome characterized by a combination of congenital heart defects, variable cleft lip/palate, short stature, microcephaly, and digital anomalies that has_material_basis_in heterozygous mutation in the MEIS2 gene on chromosome 15q14.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: STAT5B | Gene: 6777 | Disease_IDs: OMIM_245590 | Description: A syndrome that is characterized by short stature due to insensitivity to growth hormone and that has_material_basis_in homozygous mutation in the STAT5B gene on chromosome 17q21.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: FTO | Gene: 79068 | Disease_IDs: OMIM_612938 | Description: An autosomal dominant intellectual developmental disorder characterized by global developmental delay with impaired intellectual development, speech delay, nonspecific dysmorphic facial features, hypotonia, and impaired overall growth with small head circumference that has_material_basis_in heterozygous mutation in the U2AF2 gene on chromosome 19q13.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: ALDOA | Gene: 226 | Disease_IDs: OMIM_611881 | Description: A thrombophilia characterized by decreased histidine-rich glycoprotein (HRG) plasma levels and a tendency to develop thrombosis that has_material_basis_in heterozygous mutation in HRG on chromosome 3q27.3.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: GPIHBP1 | Gene: 338328 | Disease_IDs: OMIM_615947 | Description: A familial chylomicronemia syndrome characterized by refactory fasting hyperchylomicronemia, and elevated plasma triglyceride levels that has_material_basis_in homozygous or compound heterozygous mutation in the GPIHBP1 gene on chromosome 8q24.3.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: NOTCH2 | Gene: 4853 | Disease_IDs: OMIM_610205 | Description: A liver disease that is characterized by an accumulation of bile in the liver resulting from a reducted number of liver small bile ducts.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: NOTCH2 | Gene: 4853 | Disease_IDs: OMIM_102500 | Description: A disease characterized by a group of signs and symptoms that occur together and characterize a particular abnormality.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: HOXA13 | Gene: 3209 | Disease_IDs: OMIM_140000 | Description: A syndrome characterized by distal limb defects (short thumbs and first toes, clinodactyly of the fifth fingers, delayed ossification of the wrist and ankle bones), urogenital defects and that has_material_basis_in heterozygous mutation in the HOXA13 gene on chromosome 7p15.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: CPOX | Gene: 1371 | Disease_IDs: SNOMED CT_190915002 | Description: OMIM mapping confirmed by DO. [SN].'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: CPOX | Gene: 1371 | Disease_IDs: MedGen_C0342859 | Description: No description found.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DHH | Gene: 50846 | Disease_IDs: MedGen_CN068862 | Description: A gonadal dysgenesis that is characterized by a normal 46,XY karyotype along with a progressive loss of germ cells on the developing gonads of an embryo.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: DHH | Gene: 50846 | Disease_IDs: OMIM_607080 | Description: A gonadal dysgenesis that characterized by minifascicular neuropathy and that has_material_basis_in mutation in the desert hedgehog gene (DHH).'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: HFE2 | Gene: 148738 | Disease_IDs: OMIM_602390 | Description: A hemochromatosis type 2 that has_material_basis_in homozygous or compound heterozygous mutation in the HJV gene on chromosome 1q21.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: HAMP | Gene: 57817 | Disease_IDs: OMIM_613313 | Description: A hemochromatosis type 2 that has_material_basis_in homozygous mutation in the HAMP gene on chromosome 19q13.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: TFR2 | Gene: 7036 | Disease_IDs: OMIM_604250 | Description: A hemochromatosis that has_material_basis_in homozygous or compound heterozygous mutation in the TFR2 gene on chromosome 7q22.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SLC40A1 | Gene: 30061 | Disease_IDs: OMIM_606069 | Description: A hemochromatosis that has_material_basis_in heterozygous mutation in the SLC40A1 gene on chromosome 2q32.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: HK1 | Gene: 3098 | Disease_IDs: OMIM_605285 | Description: A Charcot-Marie-Tooth disease type 4 that has_material_basis_in homozygous mutation in the HK1 gene on chromosome 10q22.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: HK1 | Gene: 3098 | Disease_IDs: OMIM_235700 | Description: An amino acid metabolic disorder and a congenital nonspherocytic hemolytic anemia that is characterized by decreased levels of cellular glutathione and gamma-glutamylcysteine and hemolytic anemia that has_material_basis_in homozygous or compound heterozygous mutation in the GCLC gene on chromosome 6p12.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: GPI | Gene: 2821 | Disease_IDs: OMIM_613470 | Description: An amino acid metabolic disorder and a congenital nonspherocytic hemolytic anemia that is characterized by decreased levels of cellular glutathione and gamma-glutamylcysteine and hemolytic anemia that has_material_basis_in homozygous or compound heterozygous mutation in the GCLC gene on chromosome 6p12.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: UNC13D | Gene: 201294 | Disease_IDs: OMIM_608898 | Description: A hemophagocytic lymphohistiocytosis that has_material_basis_in a mutation of the UNC13D gene on chromosome 17q25.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: STX11 | Gene: 8676 | Disease_IDs: OMIM_603552 | Description: A hemophagocytic lymphohistiocytosis that has_material_basis_in an autosomal recessive mutation of the STX11 gene on chromosome 6q24.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: STXBP2 | Gene: 6813 | Disease_IDs: OMIM_613101 | Description: A hemophagocytic lymphohistiocytosis that has_material_basis_in a mutation of the STXBP2 gene on chromosome 19p13.2.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: JAM3 | Gene: 83700 | Disease_IDs: OMIM_613730 | Description: A central nervous system benign neoplasm that derives_from endothelial cells and that is located_in the brain.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: CCBE1 | Gene: 147372 | Disease_IDs: OMIM_235510 | Description: A lymphatic system disease characterized by he presence of intestinal lymphangiectasia, mental retardation, and characteristic facial anomalies. It is inherited in an autosomal recessive pattern. Most individuals with Hennekam syndrome have characteristic facial abnormalities, such as a flat face with accompanying puffy eyelids and hypertelorism; the nasal bridge is typically flat and the ears are typically small. Congenital extremity and genital lymphedema is present in most patients.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: LIPC | Gene: 3990 | Disease_IDs: OMIM_614025 | Description: A familial chylomicronemia syndrome characterized by hypertriglyceridemia, chylomicronemia, and decreased lipase activity that has_material_basis_in homozygous mutation in the LMF1 gene on chromosome 16p13.3.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SP110 | Gene: 3431 | Disease_IDs: OMIM_235550 | Description: A syndrome characterized by severe hypogammaglobulinemia, combined T and B cell immunodeficiency, absent lymph node germinal centers, absent tissue plasma cells, hepatic vascular occlusion, and fibrosis that has_material_basis_in homozygous or compound heterozygous mutation in the SP110 gene on chromosome 2q37.1.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: PCNA | Gene: 5111 | Disease_IDs: OMIM_615919 | Description: A peroxisomal biogenesis disorder that is characterized by sensorineural hearing loss, generalised enamel hypoplasia of the permanent dentition with normal primary dentition, and nail defects and has_material_basis_in compound heterozygous mutation in the PEX6 gene on chromosome 6p21.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SLC39A4 | Gene: 55630 | Disease_IDs: OMIM_201100 | Description: A metal metabolism disorder characterized by dermatitis around bodily openings and the tips of fingers and toes, alopecia and diarrhea and has_material_basis_in mutation in the SLC39A4 gene that encodes a zinc uptake protein and results in zinc deficiency.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SERPING1 | Gene: 710 | Disease_IDs: MedGen_CN068781 | Description: A complement deficiency that is a functional deficiency in the complement component C1 inhibitor leading to hereditary angioedema (HAE) involving swelling due to leakage of fluid from blood vessels into connective tissue.'),
#  Document(metadata={'source': 'clinvar'}, page_content='Disease: SERPING1 | Gene: 710 | Disease_IDs: SNOMED CT_234620006 | Description: A complement deficiency that is a functional deficiency in the complement component C1 inhibitor leading to hereditary angioedema (HAE) involving swelling due to leakage of fluid from blood vessels into connective tissue.'),
#  ...]

# %%
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2" )
vector_store = FAISS.from_documents(all_documents, embeddings)
# Out:
# <ipython-input-10-50c1d55c3f82>:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2" )
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
num_docs = len(vector_store.docstore._dict)  # Get the length of the internal dictionary
print(f"Number of documents in the vector store: {num_docs}")
# Out:
# Number of documents in the vector store: 10758

# %%
model = "mistralai/Mistral-7B-Instruct-v0.3"

# %%
# !pip install safetensors
# Out:
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (0.5.3)

# %%
from langchain.llms import HuggingFacePipeline
from transformers import pipeline
#create the pipeline
pipee = pipeline(
    "text-generation",
    model=model,
    torch_dtype="auto",
    device_map="cuda",
    max_new_tokens=512,
    do_sample=True,
    top_k=30,
    num_return_sequences=1,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda

# %%
custom_prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="""
    You are a biomedical expert specializing in gene-disease relationships.
    Based on the retrieved database, answer the user's question with relevant gene and disease information.

    If the query is about a **gene**, return:
    - Disease(s) associated with the gene
    - Disease ID(s)
    - Disease description(s)

    If the query is about a **disease**, return:
    - Gene(s) linked to the disease
    - Gene ID(s)
    - Disease Description

    Only use the retrieved context and avoid making assumptions.

    Context: {context}
    User Query: {question}

    Answer:
    """
)

# %%
# def refine_prompt(user_query):
#     return f"""
#     The user asked: {user_query}

#     If the query mentions a **gene**, list all related **diseases** with their **IDs** and descriptions.
#     If the query mentions a **disease**, give disease description and list all associated **genes** with their **gene IDs**.

#     # Format output neatly.
#     """

# %%
from langchain.chains import RetrievalQA


# Initialize the QA model with the custom prompt
qa = RetrievalQA.from_chain_type(
    llm=local_llm,
    chain_type="stuff",
    retriever=vector_store.as_retriever(),
    chain_type_kwargs={"prompt": custom_prompt}  # Apply the prompt template
)

# %%
  query = "Hepatitis C virus"
  result = qa.run(query)
  answer_start = result.find("Answer:") + len("Answer:")
  final_answer = result[answer_start:].strip()

  print(final_answer)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 1. Gene(s) linked to Hepatitis C virus: CCR5, IL21R, IFNL3
#     2. Gene ID(s): CCR5: OMIM:601373, IL21R: 50615, IFNL3: OMIM:607402
#
#     This is based on the retrieved database, where Hepatitis C virus (Hepacivirus hominis) is shown to be associated with the genes CCR5, IL21R, and IFNL3. Hepatitis C virus is a viral infectious disease that results in inflammation located in the liver and has symptoms including fever, fatigue, loss of appetite, nausea, vomiting, abdominal pain, clay-colored bowel movements, joint pain, and jaundice.

# %%
query = "DHTKD1"
result = qa.run(query)
result
answer_start = result.find("Answer:") + len("Answer:")
final_answer = result[answer_start:].strip()

print(final_answer)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 1. DHTKD1 is associated with the following diseases:
#         - Amino acid metabolic disorder (OMIM:204750) - This disorder involves the accumulation of argininosuccinic acid (ASA) in the blood and urine.
#         - Charcot-Marie-Tooth disease type 2 (OMIM:615025) - This is a neurodegenerative disorder characterized by the degeneration of peripheral nerves, leading to symptoms in the arms and legs such as weakness, numbness, and muscle atrophy.
#     2. DHTKD1 gene ID: 55526
#     3. DHTKD1 gene is located on chromosome 10p14. The mutations in this gene have a material basis for the aforementioned diseases, either homozygous or compound heterozygous for the amino acid metabolic disorder, or heterozygous loss-of-function mutations for the Charcot-Marie-Tooth disease type 2.

# %%
query = "severe t lymphocytopenia"
result = qa.run(query)
answer_start = result.find("Answer:") + len("Answer:")
final_answer = result[answer_start:].strip()

print(final_answer)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 1. Disease: T-Cell Deficiency
#     2. Gene(s) linked to the disease: CD3G, RAG2, NBN, IGHM, CD8A, MAGT1, PTPRC
#     3. Gene ID(s): OMIM:186740, 917, 64421, 100, 57724, 5788, 3575
#     4. Disease_IDs: OMIM:615607, HP:0005403
#     5. Disease Description: A T cell deficiency characterized by partial T-cell lymphopenia with normal numbers of B and NK cells and highly variable clinical severity that has_material_basis_in homozygous or compound heterozygous mutation in the relevant genes.
